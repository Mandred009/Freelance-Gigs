# %% [markdown]
# <a href="https://colab.research.google.com/github/Mandred009/Mandred009/blob/main/Easy_OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U git+https://github.com/madmaze/pytesseract.git
# Out:
# ...
#   Cloning https://github.com/madmaze/pytesseract.git to /tmp/pip-req-build-p7tfumd0
#   Running command git clone -q https://github.com/madmaze/pytesseract.git /tmp/pip-req-build-p7tfumd0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...

# %%
import pytesseract
from PIL import Image

# %%
# !pip uninstall opencv-python-headless==4.5.5.62 
# !pip install opencv-python-headless==4.1.2.30
# Out:
# Found existing installation: opencv-python-headless 4.1.2.30
# Uninstalling opencv-python-headless-4.1.2.30:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/cv2/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless-4.1.2.30.dist-info/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libQtCore-bbdab771.so.4.8.7
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libQtGui-903938cd.so.4.8.7
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libQtTest-1183da5d.so.4.8.7
# Proceed (y/n)? y
#   Successfully uninstalled opencv-python-headless-4.1.2.30
# ...
#   Using cached opencv_python_headless-4.1.2.30-cp37-cp37m-manylinux1_x86_64.whl (21.8 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import cv2

# %%
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

# %%
img=cv2.imread('/content/drive/MyDrive/first.png')

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
from google.colab.patches import cv2_imshow

# %%
img = cv2.resize(img, None, fx=1, fy=1, interpolation=cv2.INTER_CUBIC)

# %%
img=cv2.medianBlur(img, 1)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=505x682 at 0x7FDD6F804E50>

# %%
img.shape
# Out:
# (682, 505, 3)

# %%
extract = pytesseract.image_to_string(img)

# %%
extract=''.join(extract)
type(extract)
# Out:
# str

# %%
extract=extract.split('\n')

# %%
l=list()
for i in extract:
  if i!='' and i!=' ':
    l.append(i)
l
# Out:
# ['DIA3762',
#  'DIA 315',
#  'poe',
#  '5713',
#  '2032 —',
#  'I',
#  '4382.',
#  '-',
#  '3128.',
#  '[=-01a 1565+',
#  '6235 |',
#  'OPPOSITE',
#  'DIMENSION',
#  'ARE IDEN',
#  '\x0c']

# %%
img= cv2.rotate(img, cv2.cv2.ROTATE_90_CLOCKWISE)

# %%
img = cv2.resize(img, None, fx=1, fy=1, interpolation=cv2.INTER_CUBIC)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
img=cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=682x505 at 0x7FDD6F829350>

# %%
extract = pytesseract.image_to_string(img)

# %%
extract=''.join(extract)
type(extract)
# Out:
# str

# %%
extract=extract.split('\n')

# %%
l=list()
for i in extract:
  if i!='' and i!=' ':
    l.append(i)
l
# Out:
# ['=]', '\x0c']
